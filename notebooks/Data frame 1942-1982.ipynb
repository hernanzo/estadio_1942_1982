# %%
from pathlib import Path
import os
import glob
import pickle

# %%
import pandas as pd

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
path = '/Users/hernanadasme/Projects/estadio_1940_1980/dictionaries_1940_1982/dictionaries_1980_1982_eng/*.pickle'
dict_1980_1982_eng = {}

for file_name in glob.glob(path):
    with open(file_name, 'rb') as f:
        my_dictionary = pickle.load(f)
        
        var_name = file_name.split('/')[-1].replace('.pickle', '') # extract file name from path
        dict_1980_1982_eng[var_name] = my_dictionary

# %%
dict_1980_1982_eng
# Out:
# {'counts_english_1925_1937_1980': {'fighter': 0,
#   'training': 0,
#   'centerforward': 0,
#   'chance': 7,
#   'sprinter': 0,
#   'ring': 26,
#   'lineman': 0,
#   'line': 120,
#   'pitchers': 0,
#   'forward': 4,
#   'tackle': 2,
#   'shot': 2,
#   'kick': 0,
#   'out': 7,
#   'single': 8,
#   'crack': 9,
#   'referee': 0,
#   'sport': 39,
#   'boxing': 0,
#   'player': 1,
#   'standard': 2,
#   'knockout': 0,
#   'score': 11,
#   'team': 90,
#   'teams': 0,
#   'elgoal': 0,
#   'jersey': 1,
#   'coach': 11,
#   'handicap': 0,
#   'catch': 0,
#   'dribbling': 3,
#   'record': 136,
#   'shoot': 0,
#   'back': 4,
#   'insider': 0,
#   'winger': 0,
#   'players': 1,
#   'field': 4,
#   'shortstop': 0,
#   'second': 3,
#   'ranking': 34,
#   'match': 70,
#   'club': 298,
#   'games': 0,
#   'centroforward': 0,
#   'foul': 23},
#  'counts_english_2004_2016_1982': {'fighter': 0,
#   'training': 0,
#   'centerforward': 0,
#   'chance': 3,
#   'sprinter': 0,
#   'ring': 68,
# ...

# %%
df_1980_1982_en = pd.DataFrame.from_dict(dict_1980_1982_eng, orient='index')

# %%
df_1970_1979_en = pd.DataFrame.from_dict(dict_1970_1979_eng, orient='index')

# %%
df_1942_1949_en = pd.DataFrame.from_dict(dict_1942_1949_eng, orient='index')

# %%
df_1950_1959_en = pd.DataFrame.from_dict(dict_1950_1959_eng, orient='index')

# %%
df_1960_1969_en = pd.DataFrame.from_dict(dict_1960_1969_eng, orient='index')

# %%
df_1980_1982_en = df_1980_1982_en.sort_index(key=lambda x: x.str[-4:])

# %%
df_1970_1979_en = df_1970_1979_en.sort_index(key=lambda x: x.str[-4:])

# %%
df_1960_1969_en = df_1960_1969_en.sort_index(key=lambda x: x.str[-4:])

# %%
df_1950_1959_en = df_1950_1959_en.sort_index(key=lambda x: x.str[-4:])

# %%
df_1942_1949_en = df_1942_1949_en.sort_index(key=lambda x: x.str[-4:])

# %%
df_1960_1969_en
# Out:
#                                fighter  training  centerforward  chance  \
# counts_english_893_918_1960          1         0              0      34
# counts_english_945_970_1961          0         2              0      45
# counts_english_1002_1022_1962        0         1              0      23
# counts_english_1049_1079_1963        1         2              0      30
# counts_english_1075_1100_1964        2        15              0      11
# counts_english_1153_1177_1965        0         2              0      21
# counts_english_1204_1216_1966        0         0              0      14
# counts_english_1269_1278_1967        2         0              0      12
# counts_english_1318_1330_1968        3         0              0      11
# counts_english_1357_1370_1969        1         0              0      11
#
#                                sprinter  ring  lineman  line  pitchers  \
# counts_english_893_918_1960          13   109        0   104         0
# ...

# %%
# create a scatter plot with points instead of bars
fig, ax = plt.subplots(figsize=(40, 10))
for column in df_1942_1949_en.columns:
    ax.scatter(df_1942_1949_en.index, df_1942_1949_en[column], label=column, s=400, alpha = 0.5)

sns.set_style('darkgrid')
sns.set_palette('bright')
sns.set_context('talk')

#ax.legend()
#ax.set_xlabel('Document)
#ax.set_ylabel('Frequency')
ax.set_xticks(df_1942_1949_en.index)
plt.yticks(fontsize=20)
plt.xticks(rotation=45, fontsize=20)
#plt.legend(fontsize='20')
plt.show()

# %%
# create a scatter plot with points instead of bars
fig, ax = plt.subplots(figsize=(40, 10))
for column in df_1950_1959_en.columns:
    ax.scatter(df_1950_1959_en.index, df_1950_1959_en[column], label=column, s=400, alpha = 0.5)

sns.set_style('darkgrid')
sns.set_palette('bright')
sns.set_context('talk')

#ax.legend()
#ax.set_xlabel('Document')
#ax.set_ylabel('Frequency')
ax.set_xticks(df_1950_1959_en.index)
plt.yticks(fontsize=20)
plt.xticks(rotation=45, fontsize=20)
#plt.legend(fontsize='20')
plt.show()

# %%
# create a scatter plot with points instead of bars
fig, ax = plt.subplots(figsize=(40, 10))
for column in df_1960_1969_en.columns:
    ax.scatter(df_1960_1969_en.index, df_1960_1969_en[column], label=column, s=400, alpha = 0.5)

sns.set_style('darkgrid')
sns.set_palette('bright')
sns.set_context('talk')

#ax.legend()
#ax.set_xlabel('Document')
#ax.set_ylabel('Frequency')
ax.set_xticks(df_1960_1969_en.index)
plt.yticks(fontsize=20)
plt.xticks(rotation=45, fontsize=20)
#plt.legend(fontsize='20')
plt.show()

# %%
# create a scatter plot with points instead of bars
fig, ax = plt.subplots(figsize=(40, 10))
for column in df_1970_1979_en.columns:
    ax.scatter(df_1970_1979_en.index, df_1970_1979_en[column], label=column, s=400, alpha = 0.5)

sns.set_style('darkgrid')
sns.set_palette('bright')
sns.set_context('talk')

#ax.legend()
#ax.set_xlabel('Document')
#ax.set_ylabel('Frequency')
ax.set_xticks(df_1970_1979_en.index)
plt.yticks(fontsize=20)
plt.xticks(rotation=45, fontsize=20)
#plt.legend(fontsize='20')
plt.show()

# %%
# create a scatter plot with points instead of bars
fig, ax = plt.subplots(figsize=(40, 10))
for column in df_1980_1982_en.columns:
    ax.scatter(df_1980_1982_en.index, df_1980_1982_en[column], label=column, s=400, alpha = 0.5)

sns.set_style('darkgrid')
sns.set_palette('bright')
sns.set_context('talk')

#ax.legend()
#ax.set_xlabel('Document')
#ax.set_ylabel('Frequency')
ax.set_xticks(df_1980_1982_en.index)
plt.yticks(fontsize=20)
plt.xticks(rotation=45, fontsize=20)
#plt.legend(fontsize='20')
plt.show()

# %%
df_freq_1942_1982 = pd.concat([df_1942_1949_en, df_1950_1959_en, df_1960_1969_en, df_1970_1979_en, df_1980_1982_en])

# %%
df_freq_1942_1982.to_csv('df_freq_1942_1982.csv', index=True)

# %%
df_freq_1942_1982
# Out:
#                                fighter  training  centerforward  chance  \
# counts_english_15_27_1942            0         3              0      16
# counts_english_43_59_1943           11         1              0      39
# counts_english_76_86_1944            1         3              0      30
# counts_english_120_137_1945          7         3              0      53
# counts_english_173_189_1946          0         3              0      35
# counts_english_225_241_1947          0         2              0      15
# counts_english_277_293_1948          4         3              0      20
# counts_english_329_346_1949          0         1              0      22
# counts_english_381_398_1950          2         1              0      24
# counts_english_433_450_1951         12         0              0      18
# counts_english_486_502_1952          1         1              0      14
# counts_english_529_554_1953          5         0              0      12
# ...

# %%
# create a scatter plot with points instead of bars
fig, ax = plt.subplots(figsize=(40, 10))
for column in df_freq_1942_1982.columns:
    ax.scatter(df_freq_1942_1982.index, df_freq_1942_1982[column], label=column, s=400, alpha = 0.5)

sns.set_style('darkgrid')
sns.set_palette('bright')
sns.set_context('talk')

#ax.legend()
#ax.set_xlabel('Document')
#ax.set_ylabel('Frequency')
ax.set_xticks(df_freq_1942_1982.index)
plt.yticks(fontsize=20)
plt.xticks(rotation=45, fontsize=20)
#plt.legend(fontsize='20')
plt.show()

# %% [markdown]
# **Building a Ratio**

# %%
path = '/Users/hernanadasme/Projects/estadio_1940_1980/dictionaries_1940_1982/dictionaries_1942_1949_esp/*.pickle'
dict_1942_1949_esp = {}

for file_name in glob.glob(path):
    with open(file_name, 'rb') as f:
        # Load the dictionary from the file using pickle.load
        my_dictionary = pickle.load(f)
        
        # Create a global variable with the same name as the file name
        var_name = file_name.split('/')[-1].replace('.pickle', '') # extract file name from path
        dict_1942_1949_esp[var_name] = my_dictionary

# %%
print(len(counts_spanish_15_27_1942))
# Out:
# 45

# %%
dict_1942_1949_esp
# Out:
# {'counts_spanish_43_59_1943': {'boxeador': 82,
#   'entrenamiento': 79,
#   'centrodelantero': 48,
#   'opción': 16,
#   'velocista': 13,
#   'cuadrilátero': 8,
#   'guardalínea': 1,
#   'línea': 196,
#   'lanzador': 13,
#   'delantero': 163,
#   'barrida': 0,
#   'disparo': 3,
#   'tiro': 98,
#   'fuera': 181,
#   'individual': 55,
#   'estrella': 17,
#   'arbitro': 113,
#   'deporte': 521,
#   'boxeo': 40,
#   'jugador': 646,
#   'estandar': 2,
#   'nocaut': 3,
#   'marcador': 26,
#   'equipo': 925,
#   'equipos': 0,
#   'gol': 682,
#   'camiseta': 38,
#   'entrenador': 102,
#   'desventaja': 11,
#   'atrapar': 5,
#   'esquivar': 8,
#   'registro': 3,
#   'disparar': 2,
#   'defensa': 304,
#   'interior': 73,
#   'lateral': 8,
#   'jugadores': 0,
#   'cancha': 480,
#   'parada': 56,
#   'asistente': 17,
#   'clasificación': 23,
#   'partido': 503,
#   'institución': 67,
#   'juegos': 33,
#   'goleador': 0,
#   'infracción': 3},
#  'counts_spanish_76_86_1944': {'boxeador': 38,
# ...

# %%
rt_76_86_1944 = {key: None for key in counts_english_43_59_1943}

english_values = list(counts_english_76_86_1944.values())
spanish_values = list(counts_spanish_76_86_1944.values())

ratio_long = []
f = 0
for n in english_values:
    if english_values[f] == 0 or spanish_values[f] == 0:
        ratio_long.append(0) 
    else:
        nume = english_values[f] / spanish_values[f]
        ratio_long.append(nume)
    f += 1
    
# Iterate over the keys in the dictionary and assign values from the list to the corresponding keys
for i, key in enumerate(rt_76_86_1944.keys()):
    rt_76_86_1944[key] = ratio_long[i]

# Print the updated dictionary
print(rt_76_86_1944)
# Out:
# {'fighter': 0.02631578947368421, 'training': 0.06976744186046512, 'centerforward': 0, 'chance': 0.8571428571428571, 'sprinter': 1.0769230769230769, 'ring': 103.0, 'lineman': 0, 'line': 0.40594059405940597, 'pitchers': 0, 'forward': 0.5131578947368421, 'tackle': 0, 'shot': 13.0, 'kick': 0.03389830508474576, 'out': 0.13131313131313133, 'single': 0.4473684210526316, 'crack': 6.1923076923076925, 'referee': 0.19148936170212766, 'sport': 0.24897959183673468, 'boxing': 0.025, 'player': 0.0773067331670823, 'standard': 8.0, 'knockout': 0, 'score': 1.4583333333333333, 'team': 0.35094339622641507, 'teams': 0, 'elgoal': 0, 'jersey': 0, 'coach': 0.06837606837606838, 'handicap': 1.5384615384615385, 'catch': 0, 'dribbling': 2.0, 'record': 16.555555555555557, 'shoot': 0, 'back': 0.20588235294117646, 'insider': 1.0869565217391304, 'winger': 1.1666666666666667, 'players': 0, 'field': 0.0425531914893617, 'shortstop': 0, 'second': 1.5714285714285714, 'ranking': 0.7272727272727273, 'match': 0.72659176029
# ...

# %% [markdown]
# **Building a ratios dataframe**

# %%
rt_1944 = pd.DataFrame.from_dict(rt_76_86_1944, orient='index')
