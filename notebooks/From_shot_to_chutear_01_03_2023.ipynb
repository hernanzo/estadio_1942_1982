# %% [markdown]
# **Prototype for anglicisms seeking**
# >This notebook explores the first digitized Estadio Magazine number looking for words borrowed from English. It traces how the language of sports changed throughout the second half of the 20th Century.

# %% [markdown]
# **Loading Libraries**

# %%
import PyPDF2

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/hernanadasme/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/hernanadasme/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
import re
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# **Import pdf file from directory**
#
# >This line of code takes the pdf file from the directory and opens it using the pdf_reader.

# %%
pdf_file = open(r'/Users/hernanadasme/Projects/estadio_1940_1980/estadio_pdfs/estadio_43_59_7_05_17_12_1943.pdf', 'rb')

# %%
pdf_reader = PyPDF2.PdfReader(pdf_file)

# %%
len(pdf_reader.pages)
# Out:
# 565

# %% [markdown]
# **From pdf to txt**
#
# >This line of code extracts the text from the pdf_reader and creates a txt file called `estadio_43_59_1943`

# %%
estadio_43_59_1943 = ""

for page in pdf_reader.pages:
    estadio_43_59_1943 += page.extract_text()

# %% [markdown]
# Checking the txt file.

# %%
estadio_43_59_1943
# Out:
# '^Sfeñ*~*-\n>**\n.%Á\n^■w\'\'*<»í^S\n\\,$%\'\'■S***\n*^j .í*■•\';\'$¿fr&:\n»->/:."\'\'">&?«*í\\,#w•\'■■.rTV\n-<á-**L\nJ^ál**ap\n>f"X"\n■t"Jp\'rí>T-\'\n■M;\'.-¿\nr\'""-.\'&\n\'*»■■•/\'/;k\\>;\ni■•rJ^MllfSSiPsis----\'- :\'-W\'\nBIBLIOTECA NACIONAL\nDECHILE\nVolúmenes deestaobra\nSalaenqueseencuentra\nTabla enquesehalla\nOrden queenellatiene....\n4lj*(l*1)~^)BBIBLIOTECA NACIONAL\nDECHILE\nSección :Hemeroteca\nVolúmenes delaobra\n1253\nUbicaciónCV°V~4)\n3ÍBLÍ0TECA\n/<—\n.\n¿\n^¿>\nNUMERO-DEDICADO ALXII\nCAMPEONATO SUDAMERICANO\nDEATLETISMOM.R.\nN.°43\nPRECIO: $4.—\nJORGEEHLERS, jovenyex\\\ntraordinario atletachileno,\nqueconsiguióunadeJas]\nmejoresmarcas ene!Sud\namericano deAtletismo.\n<■;■■*..•\n*\'í*\nb**fEDERlCO HORN,elprimer\'\'arte-\nmi..chileño quepasalavarilla\ncolocada aloscuatrometros, en\nelsaltocongarrocha. Ganóesa\nprueba enelSudamericano, de-\npostrandoeltemple ylaperso-\n«alidad de«losverdaderos cam\npeones. Sueátilo esbastante\nSerfecto, comolodemuestra la\njpto.Sujuventud ysuextraordi\nnarioentusiasmo ,por*suprueba\njjavoritahandepermitirle muy\nftontbalcanzar nosóloelrecord\n|btttinental,sinoquecolocarlo en\nnivelfrancamente superior alas\nÉemósmarcassudamericanas.\n.v-«.-.v,,.,.,,„„,\nAñoII-N.°43 Publicación quincenal\nSantiago deChile,7demayode1943\nRedacción yadministración:\nCompañía 1288,2.opiso—Casilla3954—Telé*»oa=66828\nDirector: Alejandro Jaramillo N.\nEstarevistaladistribuye entodoelpaísyelextran, e\nmentelaEmpresa EditoraZig-Zag.\nSUSCRIPCIONES :\nUnaño\nSeismeses\nT—IMIIIIM II«asmvísitaSm^i\nMAY7\n$75\n■■JMSFQmTQ LEGAL\nREVISTA GRÁFICA DE\nEldeporte chileno enelcampo\ninfernacional...\nEnmuchasoportunidades, anteunaderrota\nocasional denuestros deportistas enunacom\npetencia entrepaises,hemosoídocomentarios\ndespectivos degentequevivealmargen dees\ntasactividades yquehierennuestro amorpro\npio.Losdeportistas chilenos, quesabendees\nfuerzos noblespordejarmuyenaltonuestros\nprestigios deportivos enelcampointernacio\nnal,loshanescuchado muchas veces.Personas\nincapaces detodaactividad fásica,quepoco\nonadasabendenuestrodeporte, anteelpocoafortunado desempeño dealguna denuestras\ndelegaciones deportivas alexterior, seempeñan\nendecirqueloschilenos pocovalenyquenues\ntrarazaestádecaída.\nESTADIO sienteíntimasatisfacción alrefutaraquellas apreciaciones, destacando laevi\ndenciadelaltopieenqueseencuentran las\nactividades físicas enChile;elprestigio deque\ngozaylapreponderancia quehalogrado al\ncanzar eldeporte chileno enlaAmérica del\nSur.\nSitomamos encuenta queChileesunode\nlospaísesmáspequeños delcontinente, quelapoblación deotrospaísessuperaampliamen\ntealanuestra; siagregamos queeldeporte en\nChilenuncahacontado conunapoyotécnico\nyfinanciero queestédeacuerdo consuimportanciayespecialmente consusaspiraciones, de\nbemosllegaralaconclusión dequelacalidad\nfísicadenuestros deportistas esdeprimerisi-\nmacategoría.\nTodossabemos quelosasesdeldeporte son\nelreflejodelapotencia deunaraza.Elcrack\neselproducto deunaselección. Ylacalidad\nsuperior delcrackrepresenta laexistencia de\nunagranbase,también decalidadsuperior, que\nestodoelpueblo.\nChileacabadeganar,porampliomargen, el\nXIIICampeonato Sudamericano deAtletismo,confirmando sutradicional capacidad^ eneste]deporte, elque,comoningúnotro,refleja la\naptitudfísicadeunpueblo.\nEnhombres ydamashadejadolaimpresión\nfirmeyhalagadora dequeChileesélprimer\npaísdeAmérica eneldeporte clásico. Sibien\nnoconcurrió Brasilalreciente torneo, lasmar\ncasdenuestros representantes enconjunto nos\nrevelansuperioridad también sobreaquelpaís.Peronosóloenestaactividad deportiva está\nChileenunpiedepreponderancia enAmérica.\nEnbox,enelpresente yenélpasado, nuestros\npúgiles sehanhechoadmirar enelextranjero.Éntrelos profesionales, sondetodosconocidos\nlosvaloresnuestros, yentrelosaficionados, las\nrepresentaciones -chilenas enelúltimo cam\npeonato hanconseguido siempre elprimer o\nsegundo lugar.Eltenischileno, ensucapacidaddeconjunto, sepuedeconsiderar elmejordeSudamérica enlaac ...

# %% [markdown]
# **Basic - Preprocesing**
#
# >These two funcions --preprocess_text and a tokenize-- do a basic preprocessing. The first one replaces the annoying \b, the special characters, digits and it lowers all teh text.
#
# >The tokenize function does basically two things: 1) it breaks down the txt long string into chunks and 2)it removes the stopwords (words that aren't relevant to our analysis)

# %%
def preprocess_text(text):
    # Lowercase the text
    text = text.replace('\n', '')
    pattern_1 = r'[^a-zA-Z0-9\s]'
    # Replace the special characters with an empty string
    text = re.sub(pattern_1, '', text)
    pattern_2 = r'\d+'
    # Replace the digits with an empty string
    text = re.sub(pattern_2, '', text)
    text = text.lower()
    
    return text

# %%
def tokenize(text):
    tokens = word_tokenize(text)
    tokens = [token for token in tokens if len(token) > 0]
    #tokens = [get_lemma(token) for token in tokens]
    return tokens

# %%
cleaned_estadio_43_59_1943 = preprocess_text(estadio_43_59_1943)

# %%
tokenized_estadio_43_59_1943 = tokenize(cleaned_estadio_43_59_1943)

# %%
cleaned_estadio_43_59_1943
# Out:
# 'sfewssj frwrtvljlapfxtjprtmrkirjmllfssipsis wbiblioteca nacionaldechilevolmenes deestaobrasalaenqueseencuentratabla enquesehallaorden queenellatieneljlbbiblioteca nacionaldechileseccin hemerotecavolmenes delaobraubicacincvvbltecanumerodedicado alxiicampeonato sudamericanodeatletismomrnprecio jorgeehlers jovenyextraordinario atletachilenoqueconsiguiunadejasmejoresmarcas enesudamericano deatletismobfederlco hornelprimerartemichileo quepasalavarillacolocada aloscuatrometros enelsaltocongarrocha ganesaprueba enelsudamericano depostrandoeltemple ylapersoalidad delosverdaderos campeones suetilo esbastanteserfecto comolodemuestra lajptosujuventud ysuextraordinarioentusiasmo porsupruebajjavoritahandepermitirle muyftontbalcanzar nosloelrecordbtttinentalsinoquecolocarlo ennivelfrancamente superior alasemsmarcassudamericanasvvaoiin publicacin quincenalsantiago dechiledemayoderedaccin yadministracincompaa opisocasillateloadirector alejandro jaramillo nestarevistaladistribuye entodoelpasyelextran ementelaempresa editorazigzagsuscripciones unaoseismesestimiiiim iiasmvsitasmimayjmsfqmtq legalrevista grfica deeldeporte chileno enelcampoinfernacionalenmuchasoportunidades anteunaderrotaocasional denuestros deportistas enunacompetencia entrepaiseshemosodocomentariosdespectivos degentequevivealmargen deestasactividades yquehierennuestro amorpropiolosdeportistas chilenos quesabendeesfuerzos noblespordejarmuyenaltonuestrosprestigios deportivos enelcampointernacionalloshanescuchado muchas vecespersonasincapaces detodaactividad fsicaquepocoonadasabendenuestrodeporte anteelpocoafortunado desempeo dealguna denuestrasdelegaciones deportivas alexterior seempeanendecirqueloschilenos pocovalenyquenuestrarazaestdecadaestadio siententimasatisfaccin alrefutaraquellas apreciaciones destacando laevidenciadelaltopieenqueseencuentran lasactividades fsicas enchileelprestigio dequegozaylapreponderancia quehalogrado alcanzar eldeporte chileno enlaamrica delsursitomamos encuenta quechileesunodelospasesmspequeos delcontinente quelapoblacin deotrospasessuperaampliamentealanuestra siagregamos queeldeporte enchilenuncahacontado conunapoyotcnicoyfinanciero queestdeacuerdo consuimportanciayespecialmente consusaspiraciones debemosllegaralaconclusin dequelacalidadfsicadenuestros deportistas esdeprimerisimacategoratodossabemos quelosasesdeldeporte sonelreflejodelapotencia deunarazaelcrackeselproducto deunaseleccin ylacalidadsuperior delcrackrepresenta laexistencia deunagranbasetambin decalidadsuperior queestodoelpueblochileacabadeganarporampliomargen elxiiicampeonato sudamericano deatletismoconfirmando sutradicional capacidad enestedeporte elquecomoningnotrorefleja laaptitudfsicadeunpuebloenhombres ydamashadejadolaimpresinfirmeyhalagadora dequechileeslprimerpasdeamrica eneldeporte clsico sibiennoconcurri brasilalreciente torneo lasmarcasdenuestros representantes enconjunto nosrevelansuperioridad tambin sobreaquelpasperonosloenestaactividad deportiva estchileenunpiedepreponderancia enamricaenboxenelpresente yenlpasado nuestrospgiles sehanhechoadmirar enelextranjerontrelos profesionales sondetodosconocidoslosvaloresnuestros yentrelosaficionados lasrepresentaciones chilenas enelltimo campeonato hanconseguido siempre elprimer osegundo lugareltenischileno ensucapacidaddeconjunto sepuedeconsiderar elmejordesudamrica enlaactualidad esproverbiallasuperior calidad denuestros equitadores cuyosvalores yanoslopertenecen alconciertosudamericano sinoquesucategora loshacemerecedores dealternar conlosmejores delmundo sibienenftbolestamos pordebajodeargentina yuruguay nodebeolvidarse quenoesgrande ladistancia quenossepara deestospasesquehanlogrado enmsdeunaocasinsaborear eltriunfo encampeonatos delmundoaschileenlosjuegosdefortaleza puraydehabilidad hademostrado sucapacidad superiordebiendo deparar estasituacin deprivilegioobtenida pornuestros deportistas lamejordelassatisfacciones atodosloschilenossatisfaccin queestantomsgrandeporcuantolacategora delosdeportistas deestatierrapermite achileco ...

# %%
tokenized_estadio_43_59_1943
# Out:
# ['sfewssj',
#  'frwrtvljlapfxtjprtmrkirjmllfssipsis',
#  'wbiblioteca',
#  'nacionaldechilevolmenes',
#  'deestaobrasalaenqueseencuentratabla',
#  'enquesehallaorden',
#  'queenellatieneljlbbiblioteca',
#  'nacionaldechileseccin',
#  'hemerotecavolmenes',
#  'delaobraubicacincvvbltecanumerodedicado',
#  'alxiicampeonato',
#  'sudamericanodeatletismomrnprecio',
#  'jorgeehlers',
#  'jovenyextraordinario',
#  'atletachilenoqueconsiguiunadejasmejoresmarcas',
#  'enesudamericano',
#  'deatletismobfederlco',
#  'hornelprimerartemichileo',
#  'quepasalavarillacolocada',
#  'aloscuatrometros',
#  'enelsaltocongarrocha',
#  'ganesaprueba',
#  'enelsudamericano',
#  'depostrandoeltemple',
#  'ylapersoalidad',
#  'delosverdaderos',
#  'campeones',
#  'suetilo',
#  'esbastanteserfecto',
#  'comolodemuestra',
#  'lajptosujuventud',
#  'ysuextraordinarioentusiasmo',
#  'porsupruebajjavoritahandepermitirle',
#  'muyftontbalcanzar',
#  'nosloelrecordbtttinentalsinoquecolocarlo',
#  'ennivelfrancamente',
#  'superior',
#  'alasemsmarcassudamericanasvvaoiin',
#  'publicacin',
#  'quincenalsantiago',
#  'dechiledemayoderedaccin',
#  'yadministracincompaa',
#  'opisocasillateloadirector',
#  'alejandro',
#  'jaramillo',
#  'nestarevistaladistribuye',
#  'entodoelpasyelextran',
#  'ementelaempresa',
#  'editorazigzagsuscripciones',
#  'unaoseismesestimiiiim',
#  'iiasmvsitasmimayjmsfqmtq',
#  'legalrevista',
#  'grfica',
#  'deeldeporte',
#  'chileno',
#  'enelcampoinfernacionalenmuchasoportunidades',
#  'anteunaderrotaocasional',
#  'denuestros',
#  'deportistas',
#  'enunacompetencia',
#  'entrepaiseshemosodocomentariosdespectivos',
#  'degentequevivealmargen',
#  'deestasactividades',
#  'yquehierennuestro',
#  'amorpropiolosdeportistas',
#  'chilenos',
#  'quesabendeesfuerzos',
#  'noblespordejarmuyenaltonuestrosprestigios',
#  'deportivos',
#  'enelcampointernacionalloshanescuchado',
#  'muchas',
#  'vecespersonasincapaces',
#  'detodaactividad',
#  'fsicaquepocoonadasabendenuestrodeporte',
#  'anteelpocoafortunado',
#  'desempeo',
#  'dealguna',
#  'denuestrasdelegaciones',
#  'deportivas',
#  'alexterior',
#  'seempeanendecirqueloschilenos',
#  'pocovalenyquenuestrarazaestdecadaestadio',
#  'siententimasatisfaccin',
#  'alrefutaraquellas',
#  'apreciaciones',
#  'destacando',
#  'laevidenciadelaltopieenqueseencuentran',
#  'lasactividades',
#  'fsicas',
#  'enchileelprestigio',
#  'dequegozaylapreponderancia',
#  'quehalogrado',
#  'alcanzar',
#  'eldeporte',
#  'chileno',
#  'enlaamrica',
#  'delsursitomamos',
#  'encuenta',
#  'quechileesunodelospasesmspequeos',
#  'delcontinente',
#  'quelapoblacin',
#  'deotrospasessuperaampliamentealanuestra',
#  'siagregamos',
#  'queeldeporte',
#  'enchilenuncahacontado',
#  'conunapoyotcnicoyfinanciero',
#  'queestdeacuerdo',
#  'consuimportanciayespecialmente',
#  'consusaspiraciones',
#  'debemosllegaralaconclusin',
#  'dequelacalidadfsicadenuestros',
#  'deportistas',
#  'esdeprimerisimacategoratodossabemos',
#  'quelosasesdeldeporte',
#  'sonelreflejodelapotencia',
#  'deunarazaelcrackeselproducto',
#  'deunaseleccin',
#  'ylacalidadsuperior',
#  'delcrackrepresenta',
#  'laexistencia',
#  'deunagranbasetambin',
#  'decalidadsuperior',
#  'queestodoelpueblochileacabadeganarporampliomargen',
#  'elxiiicampeonato',
#  'sudamericano',
#  'deatletismoconfirmando',
#  'sutradicional',
#  'capacidad',
#  'enestedeporte',
#  'elquecomoningnotrorefleja',
#  'laaptitudfsicadeunpuebloenhombres',
#  'ydamashadejadolaimpresinfirmeyhalagadora',
#  'dequechileeslprimerpasdeamrica',
#  'eneldeporte',
#  'clsico',
#  'sibiennoconcurri',
#  'brasilalreciente',
#  'torneo',
#  'lasmarcasdenuestros',
#  'representantes',
#  'enconjunto',
#  'nosrevelansuperioridad',
#  'tambin',
#  'sobreaquelpasperonosloenestaactividad',
#  'deportiva',
#  'estchileenunpiedepreponderancia',
#  'enamricaenboxenelpresente',
#  'yenlpasado',
#  'nuestrospgiles',
#  'sehanhechoadmirar',
#  'enelextranjerontrelos',
#  'profesionales',
#  'sondetodosconocidoslosvaloresnuestros',
#  'yentrelosaficionados',
#  'lasrepresentaciones',
#  'chilenas',
#  'enelltimo',
#  'campeonato',
#  'hanconseguido',
#  'siempre',
#  'elprimer',
#  'osegundo',
#  'lugareltenischileno',
#  'ensucapacidaddeconjunto',
#  'sepuedeconsiderar',
#  'elmejordesudamrica',
#  'enlaactualidad',
#  'esproverbiallasuperior',
#  'calidad',
#  'denuestros',
#  'equitadores',
#  'cuyosvalores',
#  'yanoslopertenecen',
#  'alconciertosudamericano',
#  'sinoquesucategora',
#  'loshacemerecedores',
#  'dealternar',
#  'conlosmejores',
#  'delmundo',
#  'sibienenftbolestamos',
#  'pordebajodeargentina',
#  'yuruguay',
#  'nodebeolvidarse',
#  'quenoesgrande',
#  'ladistancia',
#  'quenossepara',
#  'deestospasesquehanlogrado',
#  'enmsdeunaocasinsaborear',
#  'eltriunfo',
#  'encampeonatos',
#  'delmundoaschileenlosjuegosdefortaleza',
#  'puraydehabilidad',
#  'hademostrado',
#  'sucapacidad',
#  'superiordebiendo',
#  'deparar',
#  'estasituacin',
#  'deprivilegioobtenida',
#  'pornuestros',
#  'deportistas',
#  'lamejordelassatisfacciones',
#  'atodosloschilenossatisfaccin',
#  'queestantomsgrandeporcuantolacategora',
#  'delosdeportistas',
#  'deestatierrapermite',
#  'achileconfraternizar',
#  'consushermanosdeamrica',
#  'enunpiedeigualdad',
#  'juntoapasesquelosuperan',
#  'enotrosaspectos',
#  'delasactividades',
#  'humanas',
#  'yenunterreno',
#  'enqueprimanlosmssagrados',
#  'sentimientos',
#  'decaballerosidad',
#  'vdeespritu',
#  'desuperacineltenischilenoenunplanodesupremacaconclusiones',
#  'quesederivan',
#  'delcampeonato',
#  'nacionalesta',
#  'superioridad',
#  'serefiere',
#  'aindividualescaballeros',
#  'enlosquepodemos',
#  'presentar',
#  'unselectogrupo',
#  'decracks',
#  'sinoposicin',
#  'ensudamerica',
#  'endobles',
#  'yendamas',
#  'nuestra',
#  'inferioridad',
#  'esevidenteconrespecto',
#  'aargentinaelcampeonato',
#  'nacionaldetjenis',
#  'quesedesarrollenlascanchas',
#  'delstadefrancais',
#  'conlaparticipacin',
#  'decuatrodalasmsprestigiosas',
#  'figuras',
#  'deloscourts',
#  'argentinos',
#  'heraldoweissyaugusto',
#  'zappaydelescalafnmasculino',
#  'yfelisa',
#  'piarolaymarytern',
#  'ydelfemenino',
#  'adems',
#  'detodoslosjugadores',
#  'sobresalientes',
#  'delpashatenidoporvirtudconfirmar',
#  'unacreencia',
#  'queempeziarraigarennuestros',
#  'aficionadosdecididamente',
#  'acontar',
#  'delaactuacin',
#  'sobresalientequecupoaloschilenos',
#  'enelltimocampeonato',
#  'nacionalargentino',
#  'enelquiesalvador',
#  'deikllegalasemifinal',
#  'paraserbatidoporelnorteamericano',
#  'meneillmientras',
#  'hammersley',
#  'disputelttuloconelmismonotableplayerdelosestadosunidos',
#  'antequienperdienunaluchatanlucidacomoemotiva',
#  'esacreenciaesladequeeltenischilenoenloquerespecta',
#  'asumodalidad',
#  'msimnortanteestoesladeindividuales',
#  'dehombres',
#  'estdecididamenteenunplanodesuperioridadsobreelargentino',
#  'yconsecuencialmentedadoelhechodequeestosdosuasesmarcan',
#  'lapautadeestedeporteensudamrica',
#  'debeconsiderrsele',
#  'comoelprimeroenestapartedelcontinenteladerrota',
#  'delostrasandinosyasusprimeros',
#  'compromisosrevistieron',
#  'dificultadesparaweiss',
#  'yzappatantopasteelveterano',
#  'renresentante',
#  'delstadecomoricardo',
#  'sanmartn',
#  'hicieronqueambostuvieran',
#  'queemplearse',
#  'vigorosamente',
#  'paratriunfar',
#  'weissinclusodebicederunsetasurivalsrtamaryternlajugadora',
#  'argentina',
#  'nmerodelranking',
#  'desupatriaquehademostrado',
#  'enelcampeonatochilenosucapacidadestedebutpococonvincentemselhechodequesusrivales',
#  'enlassgundaruedafueran',
#  'precisamenteelnmero',
#  'unoydosdelranking',
#  'nacional',
#  'acrecentlaconfianza',
#  'delosaficionados',
#  'enordenaqueahoranohabraposibilidadalguna',
#  'comohaocurridotantasvecesqueelmscodiciado',
#  'delosttulosdelcampeonato',
#  'quedara',
#  'enpoderdeunjugador',
#  'extranjerohammersley',
#  'batiazappasinapelacin',
#  'fuerontressetsdefisonoma',
#  'casipareja',
#  'golpesimpecablesdelchileno',
#  'desdeelfondodelacancha',
#  'aderecha',
#  'eizquierda',
#  'enlosquenosesabasiapreciar',
#  'mslajustezadelostirosolafuerzayefectodecadaunodeellospocasvecesquizs',
#  'ensucarreratenmica',
#  'hayacometidohammersley',
#  'menornmerodeerroresencuanto',
#  'aweissstesehallanteundeikquenoestaba',
#  'enundaafortunadoperoquenoobstanteelloleganencuatrosetsdeluchalaboriosa',
#  'welisscomozappaycomotodoslosargentinos',
#  'engeneral',
#  'cuentaconunsaque',
#  'notoriamente',
#  'mseficazqueeldelosjugadores',
#  'nuestrosperoesmuyirregular',
#  'aunjuegoganado',
#  'contirosdeadmirable',
#  'factura',
#  'especialmente',
#  'sudrive',
#  'cruzadodeextraordinaria',
#  'violenciasucedeotroperdido',
#  'exclusivamente',
#  'porsuspropios',
#  'ycontinuados',
#  'erroresligero',
#  'parangnderrotado',
#  'elunoentressetsyelotroencuatrolaverdad',
#  'esquetalesresultadossealan',
#  'unasignificativadiferencia',
#  'decapacidadentreeltenisdeunoyotroelbinomio',
#  'chileno',
#  'compuestoporlasseoritas',
#  'lowespinoza',
#  'queperdi',
#  'anteelconjunto',
#  'argentino',
#  'pidrolatern',
#  'porylasuperioridad',
#  'delasargentinas',
#  'quedampliamentedemanifiesto',
#  'atravsdelosdossetsladolosjftndes',
#  'entelmomento',
#  'presente',
#  'encuantoasinglesmasculinos',
#  'elselectogrupodelossieteprimeros',
#  'denuestro',
#  'escalafnhammersleydeikachondo',
#  'facondi',
#  'tavernetrullenque',
#  'ygonzlez',
#  'indiscutiblemente',
#  'estensituacin',
#  'debrindar',
#  'unaexhibicin',
#  'superior',
#  'alaquepudimos',
#  'apreciar',
#  'enweissyzappasecorrobora',
#  'loqueafirmamosalconsiderar',
#  'queenelranking',
#  'argentino',
#  'figuraeneltercerlugarlucilodelcastillo',
#  'ycreemosqueenelquintocataruzzadosplayers',
#  'detandilatadaactuacin',
#  'comoeliasdeikydemritos',
#  'msomenossimilares',
#  'encircunstanciasquedeiktieneenlnuestrolanovena',
#  'clasificacinlaeliminacin',
#  'casiinmediatadezappa',
#  'yweisssibienhadebidorepercutir',
#  'enlaatraccin',
#  'delcampeonatohatenidopofefectollevaralosaficionados',
#  'aungratoconvencimiento',
#  'eldequenuestro',
#  'tenismasculinoconlaafirmacin',
#  'delosvalonesfvenes',
#  'comohammersley',
#  'achondo',
#  'ytrullenque',
#  'ylaconservacin',
#  'enapreciable',
#  'medida',
#  'desusvaliosos',
#  'reclusos',
#  'departedejugadores',
#  'comofacondideikgonzlez',
#  'ytavernemjmwmsmm',
#  'jliiscv',
#  'vrwbvaleria',
#  'donoso',
#  'nuestra',
#  'jovenjugadora',
#  'nosdiounahalagadora',
#  'sorpresa',
#  'ensuisflpartido',
#  'conlaseorita',
#  'pimdrolasibienperdi',
#  'comoiseesperabasudesempeoestuvorevestido',
#  'deatributosexcepcionalesofreci',
#  'duraluchaasucalificada',
#  'oponenteaccionando',
#  'deigualaigualymostrando',
#  'aptitudesquelasealan',
#  'comounvailoraconsagratoconsagrarse',
#  'muypronschroeder',
#  'precariam',
#  'entecolocados',
#  'enelrankingobtuvieron',
#  'elttulonacionaldedobles',
#  'ysiquisiramosseguirlahistoria',
#  'seralargalociertodelcasoesquezappaweiss',
#  'aunconelhandicap',
#  'quesignifica',
#  'lairregularidad',
#  'deweiss',
#  'superaron',
#  'adosbinomios',
#  'quessonposiblemente',
#  'lasmspoderosas',
#  'combinaciones',
#  'quepueden',
#  'formarse',
#  'ennuestropasfacondigonzlez',
#  'yachondotrullenque',
#  'aquienesganaronentresycuatrosetsrespectivamente',
#  'depasocabesealar',
#  'quelaperformance',
#  'deachondtrullenquerelativamente',
#  'decalidadpusoenevidencia',
#  'elerrordehaberdisuelto',
#  'anteriormente',
#  'estapareja',
#  'queporsujuventud',
#  'ylasnotablesdisposiciones',
#  'deamboseslademsseguroporveniryfinalmente',
#  'cabeaadirqueenbuenos',
#  'airesseforman',
#  'combinaciones',
#  'claramente',
#  'superioresalaqueestactualmente',
#  'entrenosotrosentreellaslasderusselzappa',
#  'yrusseweissunbalance',
#  'desconsoladorlaplausible',
#  'iniciativa',
#  'delafederacin',
#  'nacional',
#  'dehacervenirtambin',
#  'representantes',
#  'deltenisfemenivsjvvfsftxtycnrjitiende',
#  'adaranuestrotenisunaposicin',
#  'expectable',
#  'delaquenohadisfrutado',
#  'desdehacemuchos',
#  'aosmbenlosdobles',
#  'comoantessihalagador',
#  'escomprobarnuestro',
#  'progreso',
#  'ensinglesnoloeselverificar',
#  'queencuanto',
#  'adoblesseguimoscomosiempre',
#  'pocomsomenosentrenosotros',
#  'nuncasehaqueridocomprenderqueeljuegodeconjunto',
#  'esfundamentalmente',
#  'distintoalindividual',
#  'hayquienesllegan',
#  'aasegurar',
#  'quesonjuegosdistintos',
#  'asseexplicaporejemplo',
#  'queaugustozappasinglista',
#  'discretoseaundoblista',
#  'excepcional',
#  'yquesucompatriotarussel',
#  'deopacaactuacinenelextranjero',
#  'encalidaddesinglista',
#  'hayatenidodesempeos',
#  'enalteced',
#  'orescomodoblista',
#  'enlaspropiascanchas',
#  'dewimbledon',
#  'enestados',
#  'unidos',
#  'kramer',
#  'ylelcampennacional',
#  'andrshammersley',
#  'que',
#  'welimin',
#  'aabzappaluegobdeunmatch',
#  'menquelasuperioridad',
#  'delbchilenofuincontrarrestable',
#  'ganporyjmyrlm',
#  'imsabajomaryternyfelisapidrola',
#  'enaccin',
#  'ensingles',
#  'ydobleslasargentinas',
#  'handemostrado',
#  'sermejores',
#  'quelasnuestras',
#  'yslovaleriadonosopudoenfrentarlasenformaquehicieraposible',
#  'unespectculoatrayentevksffcttr',
#  'v',
#  'wmfcfoftemssiiimammmfelisapidrola',
#  'lagranjugadoraargentina',
#  'queparticip',
#  'enelcampeonato',
#  'nacional',
#  'yquenosdiomagnficos',
#  'espectculos',
#  'debuentenisnmero',
#  'unodelranking',
#  'argentino',
#  'esseguramente',
#  'lamejorjugadora',
#  'delcontinentereapareci',
#  'virutagonzlez',
#  'enelcampeonato',
#  'nacional',
#  'enformaquesepuedeestimar',
#  'satisfactoriaporcuantohacamuchotiempoquenoactuaba',
#  'lafotolomuestra',
#  'ensupartido',
#  'contavernequeperdiporcincosetsquefueronmuydisputados',
#  'endoblesjugconfacondi',
#  'modalidad',
#  'dondedenuevomostr',
#  'susexcepcionalescondicionesvadordeikyrenatoachondoconeliasdeikesinteresantesealar',
#  'auetodosestoslancescontrariamente',
#  'aloquenabaocurrido',
#  'conlosprecedentes',
#  'dieron',
#  'margenadisputas',
#  'laboriosas',
#  'resolvindose',
#  'lostresencincosetsgonzlez',
#  'ytaverneposiblemente',
#  'brindaron',
#  'lamejorexhibicin',
#  'tcnica',
#  'yaqueelviruta',
#  'comosiempremostr',
#  'unjuegovariadovistosoyeficiente',
#  'tantodesdeelfondodelacanchacomoenlasproximidades',
#  'delaredaspecto',
#  'esteltimoenelqueesinsuperable',
#  'senotaron',
#  'sengonzlez',
#  'losefectos',
#  'desulargaausenciadeloscourts',
#  'taverne',
#  'porsuparteactuconmucharegularidad',
#  'ytesneliasdeiksorprendi',
#  'grandementealosespectadores',
#  'aladjudicarse',
#  'losdosprimerosnodeargentina',
#  'nosliadadounexcelente',
#  'oportunidadparaestablecer',
#  'lagranventajaqueenestonosllevannuestros',
#  'amigostrasandinossucesivamente',
#  'nuestras',
#  'jugadorasliansidoeliminadasporscoresenlosquehapredominado',
#  'elyelhastallegarse',
#  'alafinalentrefelisapidrola',
#  'ymaryternnosotros',
#  'creemosquenuestro',
#  'tenispecadedemasiadofemenino',
#  'nosexplicaremos',
#  'enmuchas',
#  'denuestras',
#  'damas',
#  'subsiste',
#  'elcriterio',
#  'dequeestedeporteesunmotivodereunin',
#  'socialunmediodereunirseenunambiente',
#  'agradablemediante',
#  'unosejercicios',
#  'fsicoselegantes',
#  'ysimpticosperosecarece',
#  'deloqueconstituye',
#  'enesencia',
#  'elespritudeportivo',
#  'lasuperacinfsicamediante',
#  'unadisciplina',
#  'continuada',
#  'yrigurosa',
#  'sisequieretaldespreocupacin',
#  'tiene',
#  'comoconsecuencia',
#  'lgica',
#  'osejuegoblando',
#  'esafaltadedominiodelosdiversos',
#  'recursosylaescasez',
#  'deestosltimosquepermiten',
#  'aplayerscomolapidrola',
#  'ylatern',
#  'quetienen',
#  'losmismosmedios',
#  'queloshombresnaturalmente',
#  'querealizadosconmenorpotencia',
#  'obtenertriunfos',
#  'sobradamente',
#  'holgadoshayexcepciones',
#  'claroestyentreellasdebemos',
#  'sealaravaleria',
#  'donoso',
#  'enprimer',
#  'trmino',
#  'laactualcampeona',
#  'nacional',
#  'estalmargen',
#  'delasafirmacionesprecedentesposeerecursosjuegaconvigoryentereza',
#  'ylucesiempre',
#  'unestadofsicoquelepermiteprodigarsegenerosamenteenlacanchadeellanosdijofelisapidrola',
#  'aquienpresentdurluchaendossetsdequetuvieron',
#  'undesarrollofrancamente',
#  'lucidotienelascualidades',
#  'neceibsmililtfeispiwmwlrrtu',
#  'fmstisffwif',
#  'vmmtitc',
#  'wmfinykkbpirtlifjlimlbjimsariasparaprogresar',
#  'disponedebuennmero',
#  'derecursos',
#  'ysobretodoposeesoltura',
#  'demovimientos',
#  'loqueesprimordial',
#  'enelteniscoincidimos',
#  'plenamente',
#  'conlacampeona',
#  'argentina',
#  'yestimamos',
#  'quevaleria',
#  'donosounavezquecontrole',
#  'mejorsujuegoytengamayorconfianza',
#  'ensusmedios',
#  'serunvalorautnticodobles',
#  'damas',
#  'ydoblesmixtosestasmodalidades',
#  'nodanmuchotemaalcomentariosiindividualmente',
#  'nuestrasjugadoras',
#  'rinden',
#  'pocoenconjunto',
#  'todava',
#  'esmenosaslasseoritas',
#  'pidrolaternhanvistofacilitadaenormemente',
#  'sutareacuando',
#  'valeria',
#  'donosotengaunacompaera',
#  'adecuam',
#  'daquebienpodra',
#  'serelaoprximo',
#  'pilardelampertplayerquehamostradosorprendentes',
#  'progresos',
#  'quizsseaelinstante',
#  'oportunoparapensar',
#  'queeldoblesdamastieneentrenosotrosmayora',
#  'deedadendoblesmixtos',
#  'porlasrazones',
#  'yaapuntadaselcampeonato',
#  'tampoco',
#  'hapodidobrindarnos',
#  'resultandosquenossatisfagan',
#  'plenamenteloscuartos',
#  'semifinalesvencido',
#  'weisspordeikconanterioridad',
#  'loscuartosfinalesdelcampeonatocomprendieron',
#  'elcotejoyacitadoentrezappa',
#  'yhammersley',
#  'yotrostresentreplayers',
#  'nacionales',
#  'marcelotaverne',
#  'conefrangonzlezpericofacondi',
#  'consalsetsanteachondo',
#  'peroluegosujovencontendor',
#  'afirmsuexpedicin',
#  'ehizoprevalecer',
#  'susmayores',
#  'condiciones',
#  'fsicas',
#  'enloquerespecta',
#  'alencuentro',
#  'entrefacondi',
#  'ysalvador',
#  'deikcabesealar',
#  'queestematch',
#  'sedesarroll',
#  'ensuscomienzosenabsoluto',
#  'desacuerdo',
#  'conlascaractersticas',
#  'habitualesdeambosporcuanto',
#  'nofudeikquienatacsinofacondi',
#  'yaquelselimitaunalabordedevolucin',
#  'certeraysobriaquelepermitiadjudicarse',
#  'losdosprimerossetsperoqueenlosrestantes',
#  'resultinfructuosaantelatenacidad',
#  'defacondiylahabilidad',
#  'conqueesteltimosupodarvariedadasujuegoylaformaimpresionante',
#  'enqueatacenelquintoyltimosetcontina',
#  'msadelanicjspmgrandes',
#  'figuras',
#  'deldeporte',
#  'chilenoedithklempaenlascompetenciasdeportivas',
#  'engeneralsiempre',
#  'elaficionadobuscaconespecial',
#  'intersalguna',
#  'figura',
#  'quedestaque',
#  'condiciones',
#  'excepcionales',
#  'oqueporsusatributos',
#  'personalesdesimpata',
#  'agregadosasusaptitudes',
#  'fsicascomplete',
#  'aquel',
#  'conjuntoquelojhalaga',
#  'yseadentra',
#  'ensusentimiento',
#  'paraobligarlo',
#  'alosmscalurosos',
#  'aplausosascomosonnecesariasestasfiguras',
#  'paraelxitodetodoespectculo',
#  'deportivo',
#  'elespectador',
#  'lasdeseaenniafnsiempre',
#  'constantedeofrecer',
#  'suadmiracin',
#  'aquienlograllenarestosrequisitosenelcampeonato',
#  'sudamericano',
#  'deatletismohubounadeestasestampas',
#  'quecomonuncacomplet',
#  'eldeseopopular',
#  'edithklempau',
#  'unamuchachachilena',
#  'deaparienciafrgildecautivantesimpata',
#  'ydeaptitudes',
#  'atlticas',
#  'extraordinarias',
#  'fuedithklempau',
#  'lafigura',
#  'demayorrealcedeltorneoellasolaaport',
#  'ymediotantosalpuntajeconquechileseclasificcampen',
#  'sudamericanoenlacompetenciadedamas',
#  'ganellanzamiento',
#  'delabalaconrecordcontinental',
#  'losmetros',
#  'vallas',
#  'conmarcadeigualcategoravenci',
#  'eneldardoocupelsegundo',
#  'lugarenelsaltoaltoconlamismamarcadelavencedora',
#  'ycontribuy',
#  'consuesfuerzo',
#  'aqueelequipo',
#  'depostas',
#  'dechilequebrara',
#  'elrecordnacionalelpblico',
#  'conraznlahizosufavorita',
#  'losmsgrandes',
#  'aplausosfueronparaellaysufiguragraciosa',
#  'pasesusonrisa',
#  'unayotravezporlapistasolicitadaporelentusiasmo',
#  'popularlagranexpectativa',
#  'queexistaantelapeleadefernndezcarabantes',
#  'queddilucidada',
#  'sindarmotivo',
#  'aquesiguieran',
#  'lasdiscusioneslasuperioridad',
#  'defernndezfuevidente',
#  'enlosdiezrounds',
#  'carabantes',
#  'seviodominado',
#  'porunpgilmaestroentodoslosaspectos',
#  'delboxyquellevunataqueconstante',
#  'yefectivogorcarabantes',
#  'decidiromper',
#  'lashostilidades',
#  'ylohizocolocando',
#  'unaizquierdarpidaseguida',
#  'deunaderecha',
#  'rectaalmentnquehizoabrigarinfundadasesperanzas',
#  'dehaberconseguido',
#  'corregir',
#  'esedefectuoso',
#  'gualetazo',
#  'quetantoselecritic',
#  'enloscomienzosdesucarreraboxerilperounavezfinalizadalaprimeravueltaaliniciarselaaccindominante',
#  'deantoniofernndez',
#  'sepudoobservar',
#  'auncarabantesdesconocido',
#  'enprincipio',
#  'excesivamente',
#  'cauteloso',
#  'peroqueamedida',
#  'queavanzabaeldesenlace',
#  'termin',
#  'porconvencer',
#  'alosasistenteslequenosloestabadesconcertado',
#  'sinoquealpromediarlasegundapartedelterminaronlasdiscusioneshaceyavariosaoscuandoantonio',
#  'fernndez',
#  'mercedasusexcepcionales',
#  'condiciones',
#  'seconsagrara',
#  'comoelmejorpesowelterdelcontinente',
#  'comenz',
#  'adestacarse',
#  'enloscuadrilterosnacionales',
#  'lafiguradelestilistavaldiviano',
#  'ralcarabanteslareconocida',
#  'tenacidadelencomiable',
#  'espritu',
#  'desuperacin',
#  'delboxeador',
#  'sureoyelhechodequefernandito',
#  'adespecho',
#  'absolutodeltiempoaotrasaodemostrara',
#  'mejoresdisposicionesymayorsupremacajuntoaeseeterno',
#  'ydesconcertante',
#  'afndetodostospblicos',
#  'porasistiralderrumbe',
#  'desuspropios',
#  'doloscontribuyeron',
#  'aformarunambiente',
#  'detensinpugilstica',
#  'determinando',
#  'unarivalidad',
#  'nicamente',
#  'comparable',
#  'aaquella',
#  'queslolograron',
#  'dirimir',
#  'yafueradepocaestanislao',
#  'loayzaaguilar',
#  'yelrecordado',
#  'luisvicentinperoalparecer',
#  'elpblicochileno',
#  'estcondenadoanopoderpresenciaruncombate',
#  'enquealsereximioantonio',
#  'fernndez',
#  'seunsobretodo',
#  'deveaobligado',
#  'ademostrartodalaextraordinaria',
#  'gamadesusinnumerablesrecursossuverdadera',
#  'apostura',
#  'dehombre',
#  'deringlanotableconfianza',
#  'ensusmediosesaincomparable',
#  'prestanciadecrackautntico',
#  'determinanenlosmscalificadosrivalestaldosisdedesconciertoqueatravsdesusltimas',
#  'presentaciones',
#  'losasistentes',
#  'hubieron',
#  'deconformarse',
#  'conadmirar',
#  'tresacabadas',
#  'exhibiciones',
#  'derelevantetcnica',
#  'enquefernandito',
#  'parasalvarlabrillantezdelespectculo',
#  'sehavistoobligado',
#  'aprovocarescenas',
#  'deriesgollegandohastatenerqueestimular',
#  'alospropiosadversarios',
#  'paraaminorar',
#  'assiquiera',
#  'enparteelreflejodeunasuperioridad',
#  'realmente',
#  'abrumadoracuando',
#  'despus',
#  'detresaosdeausencia',
#  'carabantesapareci',
#  'nuevamente',
#  'enelringdelteatrocaupolcnlaimpresin',
#  'delpbliconopodasermshalagadoraaplomado',
#  'sobrioytranquilo',
#  'contrastaba',
#  'enormenteconelrecuerdo',
#  'desuterminados',
#  'losdiezroudscarabantes',
#  'reconoci',
#  'suderrotalevantando',
#  'elbrazodesuadversario',
#  'antesdequeseemitiera',
#  'elfalloelpgilvencido',
#  'seviolentoyapocadoantelacalidad',
#  'delrivalcampaa',
#  'anterior',
#  'enquedemasiado',
#  'nervioso',
#  'derrochababuencaudaldeenergasatravsdesaltosymovimientos',
#  'innecesariosqueterminaron',
#  'porconvertirloenunbailarn',
#  'empedernidolasprimeras',
#  'acciones',
#  'nodesmerecieron',
#  'ennadalaimpresin',
#  'preliminar',
#  'pasadoslosprimeros',
#  'momentosenqueambosboxeadores',
#  'sesometieron',
#  'alestudioderimatchllegasentirverdaderotemorantelosgolpesdesuadversarionohaydudadequeestaactitud',
#  'enexcesocautelosadelestilista',
#  'demuestra',
#  'claramente',
#  'lamayorpotencialidadquehanadquirido',
#  'ltimamente',
#  'losgolpes',
#  'defernandito',
#  'peroentodocasoelhechodehaberlesentido',
#  'lasmanos',
#  'nojustificadeningn',
#  'modolareaccin',
#  'deunboxeador',
#  'queftjtttilfimeeabriga',
#  'masviste',
#  'masycuesta',
#  'menosfernndez',
#  'sevioextraordinariamente',
#  'preciso',
#  'entodossusgolpesrevelando',
#  'unmejorestado',
#  'deadiestramiento',
#  'queensucombateconcarrillo',
#  'enelgrabadoconecta',
#  'suizquierda',
#  'enunpequeo',
#  'blanco',
#  'quedejalacerrada',
#  'guardia',
#  'delvaldivianonenederealizar',
#  'unacampaalucidaporlosringsdenorteamrica',
#  'pasdondetuvooportunidad',
#  'demedirsedeigualaigualconastrosdefiguracin',
#  'universalentreellosunexcampendelmundo',
#  'yotrosdelacalidaddeunjoelegn',
#  'yholman',
#  'williamsdurante',
#  'eldesarrollo',
#  'deloctavoround',
#  'comoconsecuencia',
#  'deunaizquierda',
#  'fulminante',
#  'seguida',
#  'devariosgolpescortoscolocados',
#  'alternativamente',
#  'enlacarayalestmago',
#  'carabantes',
#  'retrocedi',
#  'hastalascuerdasvisiblemente',
#  'descompuestoperosucaballeroso',
#  'rivalhaciendo',
#  'galaunavezmsdesunaturalsuficiencianoquisoapurarlasaccionesprefiriendo',
#  'dejarenelpblicolaimpresin',
#  'dehaberpodidoobtener',
#  'elfueradecombateelprofundo',
#  'silencio',
#  'delpblico',
#  'enlosprimerosrounds',
#  'delapeleadiolapautaprecisa',
#  'delaansiedaddelosespectadores',
#  'porpresenciar',
#  'uncombate',
#  'desingular',
#  'jerarqua',
#  'peroalvertranscurrir',
#  'roundtrasroundconcaractersticas',
#  'repetidasesperando',
#  'vanamentelosinstantes',
#  'deemocinenqueelmatchalentrarensufazdecisiva',
#  'setradujera',
#  'enuncotejodefuerzasequivalentes',
#  'losasistentescomenzaron',
#  'pordemostrardescontento',
#  'yterminaronporaplaudir',
#  'entusiastamente',
#  'laaccineleganteyefectiva',
#  'deantonio',
#  'fernndezpgilnacional',
#  'queapesardetodossusttulosymerecimientos',
#  'nuncahacontado',
#  'conlasimpata',
#  'incondicional',
#  'delaspopularesyaquesloseresuelvenaaplaudirlo',
#  'cuandodefraudadas',
#  'lasexpectativasdeunaposiblederrotacomienza',
#  'laadmiracin',
#  'espontnea',
#  'antelaconstantevariedad',
#  'desusnumerososrecursosconsusltimas',
#  'performances',
#  'antonio',
#  'fernndezvuelve',
#  'ahacerse',
#  'acreedor',
#  ...]

# %% [markdown]
# **Saving the file**

# %%
path = r'/Users/hernanadasme/Projects/estadio_1940_1980/estadio_43_59_7_05_17_12_1943.txt'

with open(path, 'w') as txt_file:
    txt_file.write(estadio_43_59_1943)

# %% [markdown]
# **Trial #1: a small sample of anglicisms**
#
# >I am using a short list of terms to try the code. It includes only 5 terms that have a widespread use in Revista Estadio.

# %%
tokens_english = [
'goal', 
'match', 
'forward', 
'field', 'player']

#counting ENG words in the cleaned txt and creating a dictionary with words and counts
counts_english = {}
for token in tokens_english:
    count = cleaned_estadio_43_59_1943.count(token)
    counts_english[token] = count

# %%
#checking the dictionary 
counts_english
# Out:
# {'goal': 39, 'match': 347, 'forward': 36, 'field': 44, 'player': 80}

# %%
#counting ESP words in the cleaned txt and creating a dictionary with words and counts
tokens_spanish = [
'gol', 
'partido', 
'delantero', 
'cancha', 'jugador']

#checking the dictionary 
counts_spanish = {}
for token in tokens_spanish:
    count = cleaned_estadio_43_59_1943.count(token)
    counts_spanish[token] = count
counts_spanish
# Out:
# {'gol': 706, 'partido': 504, 'delantero': 165, 'cancha': 485, 'jugador': 655}

# %% [markdown]
# **Calculating the Ratios**
#
# >This line of code creates a new dictionary that will store the English word as the key and the ratio of the English word understood. The ratio is constructed by dividing the frequency of the English word by its Spanish counterpart.

# %%
# Initialize a new dictionary with the keys from the original dictionary
ratios_dict = {key: None for key in counts_english}

# Print the new_dict
print(ratios_dict)
# Out:
# {'goal': None, 'match': None, 'forward': None, 'field': None, 'player': None}

# %%
#creating a list with the values fro teh dictionary
english_values = list(counts_english.values())
spanish_values = list(counts_spanish.values())

# %%
#checking values
print(english_values)
print(spanish_values)
# Out:
# [39, 347, 36, 44, 80]
# [706, 504, 165, 485, 655]

# %%
#calculating the ratio
ratio = []
f = 0
for n in english_values:
    nume = english_values[f] / spanish_values[f]
    ratio.append(nume)
    f += 1

# %%
#checking the ratios
ratio
# Out:
# [0.05524079320113314,
#  0.6884920634920635,
#  0.21818181818181817,
#  0.09072164948453608,
#  0.12213740458015267]

# %% [markdown]
# **Dictionary with english terms and ratios**
# >I use a  dictionary comprehension to iterate over the list and create a new dictionary with the English terms as keys and the ratios as values.

# %%
# Iterate over the keys in the dictionary and assign values from the list to the corresponding keys
for i, key in enumerate(ratios_dict.keys()):
    ratios_dict[key] = ratio[i]

# Print the updated dictionary
print(ratios_dict)
# Out:
# {'goal': 0.05524079320113314, 'match': 0.6884920634920635, 'forward': 0.21818181818181817, 'field': 0.09072164948453608, 'player': 0.12213740458015267}

# %% [markdown]
# **Trial #2: a longer sample of anglicisms**
#
# >I will try the same process but with a list of 29 English terms and their Spanish counterparts.

# %%
#creating the list of english terms 
#ADD TEH WORD RANKING
tokens_eng = ['goal','match','Forward','Field','Back','Pitchers','Wing','Shot','shoot','Player','Handicap','Kick','Second','Referee','Insider','Crack','Standard','Jersey','Foul','Knockout','Out','Record','Score','Single','Sport','Shortstop','Training','Centroforward','sprinter']

# %%
#lowercasing the terms
tokens_englow = []
for w in tokens_eng:
    word = w.lower()
    tokens_englow.append(word)

# %%
#counting ENG words in the cleaned txt and creating a dictionary with words and counts
counts_english_long = {}
for token in tokens_englow:
    count = cleaned_estadio_43_59_1943.count(token)
    counts_english_long[token] = count

# %%
#checking dictionary
counts_english_long
# Out:
# {'goal': 39,
#  'match': 347,
#  'forward': 36,
#  'field': 44,
#  'back': 41,
#  'pitchers': 1,
#  'wing': 60,
#  'shot': 34,
#  'shoot': 1,
#  'player': 80,
#  'handicap': 3,
#  'kick': 3,
#  'second': 13,
#  'referee': 28,
#  'insider': 36,
#  'crack': 488,
#  'standard': 9,
#  'jersey': 1,
#  'foul': 21,
#  'knockout': 6,
#  'out': 28,
#  'record': 258,
#  'score': 102,
#  'single': 25,
#  'sport': 100,
#  'shortstop': 1,
#  'training': 1,
#  'centroforward': 15,
#  'sprinter': 23}

# %%
len(tokens_englow)
# Out:
# 29

# %%
#creating the list of spanish terms 
tokens_esplow = ['gol', 'partido','delantero','cancha','defensa','lanzador','lateral','disparo','disparar','jugador','desventaja','patear','segundo','juez','interior','estrella','estandar','camiseta','falta','nocaut','fuera','registro','marcador','individual','deporte','parada','entrenamiento','centrodelantero','velocista']

# %%
#counting ESP words in the cleaned txt and creating a dictionary with words and counts
counts_spanish_long = {}
for token in tokens_esplow:
    count = cleaned_estadio_43_59_1943.count(token)
    counts_spanish_long[token] = count

# %%
#checking dictionary
counts_spanish_long
# Out:
# {'gol': 706,
#  'partido': 504,
#  'delantero': 165,
#  'cancha': 485,
#  'defensa': 304,
#  'lanzador': 13,
#  'lateral': 8,
#  'disparo': 3,
#  'disparar': 2,
#  'jugador': 655,
#  'desventaja': 11,
#  'patear': 9,
#  'segundo': 361,
#  'juez': 10,
#  'interior': 73,
#  'estrella': 17,
#  'estandar': 2,
#  'camiseta': 38,
#  'falta': 165,
#  'nocaut': 3,
#  'fuera': 181,
#  'registro': 3,
#  'marcador': 28,
#  'individual': 56,
#  'deporte': 561,
#  'parada': 56,
#  'entrenamiento': 79,
#  'centrodelantero': 49,
#  'velocista': 13}

# %%
len(counts_spanish_long)
# Out:
# 29

# %%
# Initialize a new dictionary with the keys from the original dictionary
ratios_dict_long = {key: None for key in counts_english_long}

# Print the new_dict
print(ratios_dict_long)

english_values_long = list(counts_english_long.values())
spanish_values_long = list(counts_spanish_long.values())

ratio_long = []
f = 0
for n in english_values_long:
    nume = english_values_long[f] / spanish_values_long[f]
    ratio_long.append(nume)
    f += 1


# Iterate over the keys in the dictionary and assign values from the list to the corresponding keys
for i, key in enumerate(ratios_dict_long.keys()):
    ratios_dict_long[key] = ratio_long[i]

# Print the updated dictionary
print(ratios_dict_long)
# Out:
# {'goal': None, 'match': None, 'forward': None, 'field': None, 'back': None, 'pitchers': None, 'wing': None, 'shot': None, 'shoot': None, 'player': None, 'handicap': None, 'kick': None, 'second': None, 'referee': None, 'insider': None, 'crack': None, 'standard': None, 'jersey': None, 'foul': None, 'knockout': None, 'out': None, 'record': None, 'score': None, 'single': None, 'sport': None, 'shortstop': None, 'training': None, 'centroforward': None, 'sprinter': None}
# {'goal': 0.05524079320113314, 'match': 0.6884920634920635, 'forward': 0.21818181818181817, 'field': 0.09072164948453608, 'back': 0.13486842105263158, 'pitchers': 0.07692307692307693, 'wing': 7.5, 'shot': 11.333333333333334, 'shoot': 0.5, 'player': 0.12213740458015267, 'handicap': 0.2727272727272727, 'kick': 0.3333333333333333, 'second': 0.036011080332409975, 'referee': 2.8, 'insider': 0.4931506849315068, 'crack': 28.705882352941178, 'standard': 4.5, 'jersey': 0.02631578947368421, 'foul': 0.12727272727272726, 'knockout': 2.0, 'out': 0.15469613259668508, 'record': 86.0, 'score': 3.642857142857143, 'single': 0.44642857142857145, 'sport': 0.17825311942959002, 'shortstop': 0.017857142857142856, 'training': 0.012658227848101266, 'centroforward': 0.30612244897959184, 'sprinter': 1.7692307692307692}

# %%
len(ratios_dict_long)
# Out:
# 29

# %%
df = pd.DataFrame(ratios_dict_long, index=[0])

# %%
df.head()
# Out:
#        goal     match   forward     field      back  pitchers  wing  \
# 0  0.055241  0.688492  0.218182  0.090722  0.134868  0.076923   7.5
#
#         shot  shoot    player  ...  knockout       out  record     score  \
# 0  11.333333    0.5  0.122137  ...       2.0  0.154696    86.0  3.642857
#
#      single     sport  shortstop  training  centroforward  sprinter
# 0  0.446429  0.178253   0.017857  0.012658       0.306122  1.769231
#
# [1 rows x 29 columns]

# %% [markdown]
# **REGULAR EXPRESSIONS**
#
# This is the solution to problem of workds squished together, and to letter spacing issues.

# %%
# Out:
# 126
