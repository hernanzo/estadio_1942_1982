# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
import re
import numpy as np
import os
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/hernanadasme/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/hernanadasme/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def function_1(string):
    words = string.split()
    for i in range(len(words)):
        if words[i][0] == "y":
            words[i] = "y " + words[i][1:]
    return " ".join(words)

def function_2(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("en"):
            words[i] = "en " + words[i][2:]
    return " ".join(words)

def function_3(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("los"):
            words[i] = "los " + words[i][3:]
    return " ".join(words)

def function_4(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("las"):
            words[i] = "las " + words[i][3:]
    return " ".join(words)

def function_5 (string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("el"):
            words[i] = "el " + words[i][2:]
    return " ".join(words)

def function_6(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("desde"):
            words[i] = "desde " + words[i][5:]
    return " ".join(words)

def function_7(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("copa"):
            words[i] = "copa " + words[i][4:]
    return " ".join(words)

def function_8(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("como"):
            words[i] = "como " + words[i][4:]
    return " ".join(words)

def function_9(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("todos"):
            words[i] = "todos " + words[i][5:]
    return " ".join(words)

def function_10(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("sobre"):
            words[i] = "sobre " + words[i][5:]
    return " ".join(words)

def function_11(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("por"):
            words[i] = "por " + words[i][3:]
    return " ".join(words)

def function_12(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("cosas"):
            words[i] = "cosas " + words[i][5:]
    return " ".join(words)

def function_13(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("años"):
            words[i] = "años " + words[i][4:]
    return " ".join(words)

def function_14(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("para"):
            words[i] = "para " + words[i][4:]
    return " ".join(words)

def function_15(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("otros"):
            words[i] = "otros " + words[i][5:]
    return " ".join(words)

def function_16(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("no"):
            words[i] = "no " + words[i][2:]
    return " ".join(words)

def function_17(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("pero"):
            words[i] = "pero " + words[i][4:]
    return " ".join(words)

def function_18(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("quizás"):
            words[i] = "quizás " + words[i][6:]
    return " ".join(words)

def function_19(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("horas"):
            words[i] = "horas " + words[i][5:]
    return " ".join(words)

def function_20(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("ahora"):
            words[i] = "ahora " + words[i][5:]
    return " ".join(words)

def function_21(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("han"):
            words[i] = "han " + words[i][3:]
    return " ".join(words)

def function_22(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("aveces"):
            words[i] = "aveces " + words[i][6:]
    return " ".join(words)

def function_23(string):
    new_string = string.replace("queen", "que en")
    return new_string

def function_24(string):
    new_string = string.replace("alos", "a los ")
    new_string = new_string.replace("sehan", "se han ")
    return new_string

def function_25(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("cómo"):
            words[i] = "cómo " + words[i][4:]
    return " ".join(words)

def function_26(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("días"):
            words[i] = "días " + words[i][4:]
    return " ".join(words)

def function_27(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("dias"):
            words[i] = "dias " + words[i][4:]
    return " ".join(words)

def function_28(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("jugó"):
            words[i] = "jugó " + words[i][4:]
    return " ".join(words)

def function_29(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("allí"):
            words[i] = "allí " + words[i][4:]
    return " ".join(words)

def function_30(string):
    new_string = string.replace(" hasido", " ha sido ")
    return new_string

def function_31(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("tengo"):
            words[i] = "tengo " + words[i][5:]
    return " ".join(words)

def function_32(string):
    new_string = string.replace("quehemos", " que hemos ")
    return new_string

def function_33(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("casos"):
            words[i] = "casos " + words[i][5:]
    return " ".join(words)

def function_34(string):
    new_string = string.replace("sehavisto", " se ha visto ")
    new_string = new_string.replace("lohemos", " lo hemos ")
    new_string = new_string.replace("seleha", " se le ha ")
    new_string = new_string.replace("estáen", " está en ")
    new_string = new_string.replace("fácil", " fácil ")
    new_string = new_string.replace("lohizo", " lo hizo ")
    return new_string

def function_35(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("visto"):
            words[i] = "visto " + words[i][5:]
    return " ".join(words)

# %%
#master function to run it all
def master_function_1(input_string):
    # Define a list of functions to apply
    function_list = [function_1, function_2, function_3, function_4, function_5, function_6, function_7, function_8, function_9, function_10, 
                     function_11, function_12, function_13, function_14, function_15, function_16, function_17, function_18, function_19, function_20, function_21, function_22, function_23, function_24, function_25, function_26, function_27, function_28, function_29, function_30, function_31, function_32, function_33, function_34, function_35]

    # Apply each function in the list to the input string
    for function in function_list:
        input_string = function(input_string)

    # Return the final result
    return input_string

# %%
def clean_txt_2(txt_dir, clean_txt_dir):
    for filename in os.listdir(txt_dir):
        if filename.endswith('.txt'):
            filepath = os.path.join(txt_dir, filename)
            with open(filepath, 'r') as f:
                text = f.read()
            cleaned_text = master_function_1(text)
            cleaned_filepath = os.path.join(clean_txt_dir, filename)
            with open(cleaned_filepath, 'w') as f:
                f.write(cleaned_text)

# %%
clean_path = r'/Users/hernanadasme/Projects/estadio_1940_1980/estadio_pdfs/clean_txts_1958'
clean_txt_path_2 = r'/Users/hernanadasme/Projects/estadio_1940_1980/estadio_pdfs/clean_txts_1958_2'
clean_txt_2(clean_path, clean_txt_path_2)

# %%
with open(r'/Users/hernanadasme/Projects/estadio_1940_1980/estadio_txt/cleaned_notebook_1940_1949/estadio_15_27_1942.txt', encoding='utf-8-sig') as es_1942: 
    es_1942 = es_1942.read()

# %%
es_1942
# Out:
# 'año publicación quincenal santiago de chile deabrilde vif redacción yadministración ij compañía piso dásifta fono director alejandro jararriilló fotografías exclusivas carlos martín eugertfoj ciarcía distribuidor paratodoelpaja edmc sfao pizarro rojas mfc wrced casilla teléfono santiago edwards casilla valparaíé gié__i íri clí _f eifc uc eó ió enel concurso internacional de equitación último chile havencidocompitiendo conadversarios decondiciones magníficas especialmente porlagrancalidad de sus cabalgaduras chile haconquistado unavez más enestecertamen triunfos quevienanaconfirmar lainsuperable clasedenuestros jinetes yquelocolocanenelprimerlugardel continente argentina haciendo galadegranespíritu deluchavenció enlaspruebas de adiestramientoe individual paramilitares clasificándose enforma muy merecidaenel segundo puesto tercero brasilcuarto perúyquinto bolivla elresultado del concurso hípico internacional