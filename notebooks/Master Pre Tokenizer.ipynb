# %% [markdown]
# **Master Pre_Tokenizer**
# This notebook helps separating more words in order to effectively tokenize the text

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
import re
import numpy as np
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/hernanadasme/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/hernanadasme/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# **Spliting words smugged together**
# > List of functions to separate words

# %%
def function_1(string):
    words = string.split()
    for i in range(len(words)):
        if words[i][0] == "y":
            words[i] = "y " + words[i][1:]
    return " ".join(words)

def function_2(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("en"):
            words[i] = "en " + words[i][2:]
    return " ".join(words)

def function_3(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("los"):
            words[i] = "los " + words[i][3:]
    return " ".join(words)

def function_4(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("las"):
            words[i] = "las " + words[i][3:]
    return " ".join(words)

def function_5 (string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("el"):
            words[i] = "el " + words[i][2:]
    return " ".join(words)

def function_6(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("desde"):
            words[i] = "desde " + words[i][5:]
    return " ".join(words)

def function_7(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("copa"):
            words[i] = "copa " + words[i][4:]
    return " ".join(words)

def function_8(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("como"):
            words[i] = "como " + words[i][4:]
    return " ".join(words)

def function_9(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("todos"):
            words[i] = "todos " + words[i][5:]
    return " ".join(words)

def function_10(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("sobre"):
            words[i] = "sobre " + words[i][5:]
    return " ".join(words)

def function_11(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("por"):
            words[i] = "por " + words[i][3:]
    return " ".join(words)

def function_12(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("cosas"):
            words[i] = "cosas " + words[i][5:]
    return " ".join(words)

def function_13(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("años"):
            words[i] = "años " + words[i][4:]
    return " ".join(words)

def function_14(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("para"):
            words[i] = "para " + words[i][4:]
    return " ".join(words)

def function_15(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("otros"):
            words[i] = "otros " + words[i][5:]
    return " ".join(words)

def function_16(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("no"):
            words[i] = "no " + words[i][2:]
    return " ".join(words)

def function_17(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("pero"):
            words[i] = "pero " + words[i][4:]
    return " ".join(words)

def function_18(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("quizás"):
            words[i] = "quizás " + words[i][6:]
    return " ".join(words)

def function_19(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("horas"):
            words[i] = "horas " + words[i][5:]
    return " ".join(words)

def function_20(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("ahora"):
            words[i] = "ahora " + words[i][5:]
    return " ".join(words)

def function_21(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("han"):
            words[i] = "han " + words[i][3:]
    return " ".join(words)

def function_22(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("aveces"):
            words[i] = "aveces " + words[i][6:]
    return " ".join(words)

def function_23(string):
    new_string = string.replace("queen", "que en")
    return new_string

def function_24(string):
    new_string = string.replace("alos", "a los ")
    new_string = new_string.replace("sehan", "se han ")
    return new_string

def function_25(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("cómo"):
            words[i] = "cómo " + words[i][4:]
    return " ".join(words)

def function_26(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("días"):
            words[i] = "días " + words[i][4:]
    return " ".join(words)

def function_27(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("dias"):
            words[i] = "dias " + words[i][4:]
    return " ".join(words)

def function_28(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("jugó"):
            words[i] = "jugó " + words[i][4:]
    return " ".join(words)

def function_29(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("allí"):
            words[i] = "allí " + words[i][4:]
    return " ".join(words)

def function_30(string):
    new_string = string.replace(" hasido", " ha sido ")
    return new_string

def function_31(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("tengo"):
            words[i] = "tengo " + words[i][5:]
    return " ".join(words)

def function_32(string):
    new_string = string.replace("quehemos", " que hemos ")
    return new_string

def function_33(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("casos"):
            words[i] = "casos " + words[i][5:]
    return " ".join(words)

def function_34(string):
    new_string = string.replace("sehavisto", " se ha visto ")
    new_string = new_string.replace("lohemos", " lo hemos ")
    new_string = new_string.replace("seleha", " se le ha ")
    new_string = new_string.replace("estáen", " está en ")
    new_string = new_string.replace("fácil", " fácil ")
    new_string = new_string.replace("lohizo", " lo hizo ")
    return new_string

def function_35(string):
    words = string.split()
    for i in range(len(words)):
        if words[i].startswith("visto"):
            words[i] = "visto " + words[i][5:]
    return " ".join(words)


def function_36(string):
    new_string = string.replace("aside", " asi de ")
    return new_string


def function_37(string):
    new_string = string.replace("alcanzó", " alcanzó ")
    return new_string

# %%
#master function to run it all
def master_function_1(input_string):
    # Define a list of functions to apply
    function_list = [function_1, function_2, function_3, function_4, function_5, function_6, function_7, function_8, function_9, function_10, 
                     function_11, function_12, function_13, function_14, function_15, function_16, function_17, function_18, function_19, function_20, function_21, function_22, function_23, function_24, function_25, function_26, function_27, function_28, function_29, function_30, function_31, function_32, function_33, function_34, function_35, function_36, function_37]

    # Apply each function in the list to the input string
    for function in function_list:
        input_string = function(input_string)

    # Return the final result
    return input_string

# %%
#master function to run it all
def master_function_2(input_string):
    # Define a list of functions to apply
    function_list = [function_1, function_2, function_3, function_4, function_5, function_6, function_7, function_8, function_9, function_10, 
                     function_11, function_12, function_13, function_14, function_15, function_16, function_17, function_18, function_19, function_20, function_21, function_22, function_23, function_24, function_25, function_26, function_27, function_28, function_29, function_30, function_31, function_32, function_33, function_34, function_35, function_36, function_37]

    # Apply each function in the list to the input string
    for function in function_list:
        input_string = function(input_string)

    # Return the final result
    return input_string

# %%
#master function to run it all
def master_function_3(input_string):
    # Define a list of functions to apply
    function_list = [function_1, function_2, function_3, function_4, function_5, function_6, function_7, function_8, function_9, function_10, 
                     function_11, function_12, function_13, function_14, function_15, function_16, function_17, function_18, function_19, function_20, function_21, function_22, function_23, function_24, function_25, function_26, function_27, function_28, function_29, function_30, function_31, function_32, function_33, function_34, function_35, function_36, function_37]

    # Apply each function in the list to the input string
    for function in function_list:
        input_string = function(input_string)

    # Return the final result
    return input_string

# %%
#master function to run it all
def master_function_4(input_string):
    # Define a list of functions to apply
    function_list = [function_1, function_2, function_3, function_4, function_5, function_6, function_7, function_8, function_9, function_10, 
                     function_11, function_12, function_13, function_14, function_15, function_16, function_17, function_18, function_19, function_20, function_21, function_22, function_23, function_24, function_25, function_26, function_27, function_28, function_29, function_30, function_31, function_32, function_33, function_34, function_35, function_36, function_37]

    # Apply each function in the list to the input string
    for function in function_list:
        input_string = function(input_string)

    # Return the final result
    return input_string

# %% [markdown]
# **Test the Functions**

# %%
with open(r'/Users/hernanadasme/Projects/estadio_1940_1980/estadio_txt/cleaned_1950_1959/cleaned_estadio_788_813_1958.txt', encoding='utf-8-sig') as es_1958: 
    es_1958 = es_1958.read()

# %% [markdown]
# **Calculating the ammount of tokens by only tokenizing**

# %%
def tokenize(text):
    tokens = word_tokenize(text)
    tokens = [token for token in tokens if len(token) > 0]
    #tokens = [get_lemma(token) for token in tokens]
    return tokens

# %%
#tokenizing the orginial documet
tokens_1958 = tokenize(es_1958)

# %%
#counting tokens
len(tokens_1958)
# Out:
# 239830

# %%
#applying master function 1
tokens_1_1958 = master_function_1(es_1958)

# %%
#tokenizing the results of function 1
tokenized_1_1958 = tokenize(tokens_1_1958)

# %%
#counting tokens
len(tokenized_1_1958)
# Out:
# 289260

# %%
#applying master function 2
tokens_2_1958 = master_function_2(tokens_1_1958)

# %%
#tokenizing the results of function 2
tokenized_2_1958 = tokenize(tokens_2_1958)

# %%
#counting tokens
len(tokenized_2_1958)
# Out:
# 292624

# %%
#applying master function 3
tokens_3_1958 = master_function_3(tokens_2_1958)

# %%
#tokenizing the results of function 3
tokenized_3_1958 = tokenize(tokens_3_1958)

# %%
#counting tokens
len(tokenized_3_1958)
# Out:
# 292789

# %%
tokens_4_1958 = master_function_4(tokens_3_1958)

# %%
#tokenizing the results of function 3
tokenized_4_1958 = tokenize(tokens_4_1958)

# %%
#counting tokens
len(tokenized_4_1958)
# Out:
# 292803

# %%
tokens_4_1958
# Out:
# 'estadio aeslalíneaaéreaparael qourmet los masexquisitos menúspremiados en concursos internacionalesybebidasdefamamundial sesirven anuestroshuéspedesenunaatmósfera decordialhospitalidad tantradicionalen lufthansa y mientras vdgozadelinsuperable confortelpoderoso cuatrimotor super soberano del espaciosedesliza serenohacia supuntodedestinobaoelmandodeexperimentados como doros desde y abienvenido abordo reserve supasaje en su agenaadeviajes oconsulte anuestro agente general agencia marítima ltda agustinas tercer piso casilla fono santiagov wipps ri tf bg ííjíg fg goy ffft tflr uo s__fgjr íb pí sfa ba sgy pi ns smbs ififs sfb sí ss aioir eb síí sre bg aa sftnp eitla sí sase íra ss psb ffsrgs bss slgi eg fi rt síl so srn_ in sa mi sie sisai scpi bjireniii ci ba ip lo sí ooh ftg st síg nip zpw abpsapio si stg bílialasasigg rpa nsoalili ic itie un ris impy papósito legql ij tí escuchaba los últimos lminutos delrelatomimente estabaenotraparte rondaba por las playasde copa cabana y veíaa los 
# ...
